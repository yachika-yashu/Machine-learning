# %% [markdown]
# <a href="https://colab.research.google.com/github/yachika-yashu/Machine-learning/blob/main/perceptron_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  the Perceptron in Scikit-learn is a tool for finding a linear decision boundary that optimally separates two classes in a dataset, provided the data is linearly separable.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron

# %%
df=pd.read_csv("/content/drive/MyDrive/Deep learning/placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %% [markdown]
# ab isk upar perceptron chla k decision boundary bnani hai, in order to calculate line equation it will calculate w1,w2,b as 2d input

# %%
from re import X
X=df.iloc[:,0:2]
y= df.iloc[:,-1]
p = Perceptron()
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.intercept_  #b
# Out:
# array([-25.])

# %%
p.coef_  #w1,w2
# Out:
# array([[ 40.26, -36.  ]])

# %% [markdown]
# https://rasbt.github.io/mlxtend/user_guide/plotting/plot_decision_regions/#plot_decision_regions-visualize-the-decision-regions-of-a-classifier
#
# See at the bottom for full review
# library to plot decision boundary on x,y after fit

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=1)  #X must be a NumPy array. so use X.values, legend=1 to specify the legend location. No legend if legend is 0.

# Adding axes annotations
plt.xlabel('cgpa')
plt.ylabel('resume Score')
plt.title('cgpa vs score')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
